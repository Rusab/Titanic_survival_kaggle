# %% [markdown]
# <h1>View Main Dataset</h1>

# %%
import numpy as np
import pandas as pd
from matplotlib import style
from matplotlib import pyplot as plt
style.use('dark_background')

titanic_data = pd.read_csv("train.csv")
titanic_data = titanic_data.replace(("male", "female"), (0,1))
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
x = titanic_data.loc[titanic_data['Survived'] == 1]
plot1 = plt.figure(1)
x.Age.plot(kind = "hist", color = 'white', edgecolor='black', figsize=(10, 7))
plot2 = plt.figure(2)
titanic_data.Age.plot(kind = "hist", color = 'white', edgecolor='black', figsize=(10, 7))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-66188fb4e84e> in <module>
#       1 x = titanic_data.loc[titanic_data['Survived'] == 1]
# ----> 2 plot1 = x.figure(1)
#       3 x.Age.plot(kind = "hist", color = 'white', edgecolor='black', figsize=(10, 7))
#       4 plot2 = x.figure(2)
#       5 titanic_data.Age.plot(kind = "hist", color = 'white', edgecolor='black', figsize=(10, 7))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'figure'
